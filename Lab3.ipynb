# %%
import math
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return "error" if b == 0 else a / b
def sin(x):
    return math.sin(math.radians(x))
def cos(x):
    return math.cos(math.radians(x))
def tan(x):
    try:
        return math.tan(math.radians(x))
    except:
        return "Undefined"
    define main():
    print("Scientific Calculator")
    print("1.Add")
    print("2.Sub")
    print("3.Mul")
    print("4.Div")
    print("5.Sin")
    print("6.Cos")
    print("7.Tan")
    pr
# Out:
#   Cell In[1], line 19
#     define main:
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# def multiply_function(a,b):
#     result = a * b
#     rerurn2 =  result * result
#     return result, result2
#     numbers_list= [1,2,3]
#     multiplier_list = [2,4]
#     for n in numbers_list:
#     print("      ")
#     for m in multiplier_list:
#         current_answer, current_answer2 = multiply_function(n,m)
#         print("The answer to %d * %d is : " %(n,m),current_answer)
#         print("The result of this squared is :",current_answer2)

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
x= lambda a,b,c: a + b + c
print(x(5,6,2))
# Out:
# 13

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.append("Honda")
print(cars)
# Out:
# ['Ford', 'Swift', 'Vano', 'Valvo', 'BMW', 'TATA', 'Tyota', 'Honda']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.append("Honda")
cars.pop(1)
print(cars)
# Out:
# ['Ford', 'Vano', 'Valvo', 'BMW', 'TATA', 'Tyota', 'Honda']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.append("Honda")
cars.pop(0)
print(cars)
# Out:
# ['Swift', 'Vano', 'Valvo', 'BMW', 'TATA', 'Tyota', 'Honda']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.append("Honda")
cars.pop(1)
cars.remove("Valvo")
print(cars)
# Out:
# ['Ford', 'Vano', 'BMW', 'TATA', 'Tyota', 'Honda']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
print(cars.count("Valvo"))
# Out:
# 1

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
print(cars.count("Ford"))
# Out:
# 1

# %%
a = ["Ford","Swift"]
b = ["Valvo","Swift","BMW"]
a.extend(b)
print(a)
# Out:
# ['Ford', 'Swift', 'Valvo', 'Swift', 'BMW']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.reverse()
print(cars)
# Out:
# ['Tyota', 'TATA', 'BMW', 'Valvo', 'Vano', 'Swift', 'Ford']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
print(cars.index("Swift"))
# Out:
# 1

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
print(cars.index("Vano"))
# Out:
# 2

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.sort()
print(cars)
# Out:
# ['BMW', 'Ford', 'Swift', 'TATA', 'Tyota', 'Valvo', 'Vano']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
b = cars.copy()
print(b)
# Out:
# ['Ford', 'Swift', 'Vano', 'Valvo', 'BMW', 'TATA', 'Tyota']

# %%
cars = ["Ford", "Swift","Vano","Valvo","BMW","TATA","Tyota"]
cars.clear()
print(cars)
# Out:
# []

# %%
practiceFile = open('File.txt','r')
for line in practiceFile:
    print(line)

# %%
practice_File = open('Practice_file_for_File.txt','w')
practiceFile_write("I am adding this to string")

# %%
import datetime
current_time = datetime.datetime.now()
print(current_time)
# Out:
# 2025-12-12 13:20:36.501440

# %%
import antigravity

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4])
plt.ylabel('some number')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Text(0, 0.5, 'some number')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4])

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4])
plt.ylabel('some number')
plt.xlabel('A meaningless axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4,5],[1,4,9,50,2])
plt.ylabel('some number')
plt.xlabel('A meaningless axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,50,2],'go')

# %%
plt.plot([1,2,3,4,5],[1,4,9,50,2],'r+')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4,5],[1,4,9,50,2],'-',linewidth=2.0)
plt.axis([0,10,0,60])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4,5],[1,4,9,50,2],'-',linewidth=5.0)
plt.axis([0,10,0,60])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4,5],[1,4,9,50,2],'-',linewidth=2.0)
plt.axis([0,10,0,60])
plt.xticks([0,5,10])
plt.yticks([0,25,50,60])
plt.show()

# %%
import mathplotlib.pyplot as ply
X = range(1,50)
Y = [value * 3 forvalue in X]
print("values of X:")
print(range(1,50))
print("Values of Y (trice of X):")
print(Y)
plt.plot(X,Y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title("Draw a line.")
plt.show()
# Out:
#   Cell In[1], line 3
#     Y = [value * 3 forvalue in X]
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
